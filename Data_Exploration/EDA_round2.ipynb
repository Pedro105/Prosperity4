# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import Image, Markdown, display

from generate_round2_plots import (
    OUTPUT_DIR,
    load_prices,
    load_trades,
    plot_displayed_depth,
    plot_imbalance_signal,
    plot_microprice_edge,
    plot_midprice_and_trend,
    plot_osmium_maker_diagnostics,
    plot_realized_volatility,
    plot_spread_regimes,
    plot_trade_activity,
    write_summary,
)

sns.set_theme(style="whitegrid")

prices = load_prices()
trades = load_trades()

prices.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                 --------------  -----
#  0   day;timestamp;product;bid_price_1;bid_volume_1;bid_price_2;bid_volume_2;bid_price_3;bid_volume_3;ask_price_1;ask_volume_1;ask_price_2;ask_volume_2;ask_price_3;ask_volume_3;mid_price;profit_and_loss  20000 non-null  object
# dtypes: object(1)
# memory usage: 156.4+ KB

# %%
plot_midprice_and_trend(prices)
plot_spread_regimes(prices)
plot_imbalance_signal(prices)
plot_microprice_edge(prices)
plot_realized_volatility(prices)
plot_displayed_depth(prices)
plot_trade_activity(trades)
plot_osmium_maker_diagnostics(prices)
write_summary(prices, trades)

summary_path = OUTPUT_DIR / "plot_summary.txt"
display(Markdown("## Plot Summary"))
display(Markdown(f"```text\n{summary_path.read_text()}\n```"))

plot_files = [
    "midprice_paths_and_trend.png",
    "spread_regimes.png",
    "imbalance_signal.png",
    "microprice_edge_signal.png",
    "realized_volatility_regimes.png",
    "displayed_depth_profile.png",
    "trade_activity_intensity.png",
    "osmium_maker_diagnostics.png",
]

[(name, (OUTPUT_DIR / name).exists()) for name in plot_files]

# %%
for name in plot_files:
    path = OUTPUT_DIR / name
    display(Markdown(f"### {name}"))
    display(Image(filename=str(path)))
